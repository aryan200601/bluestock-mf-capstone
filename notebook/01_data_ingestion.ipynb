# %%
import pandas as pd
import os

# %%
data_path = "../data/raw"

csv_files = [f for f in os.listdir(data_path) if f.endswith(".csv")]

print(csv_files)
# Out:
# ['axis_bluechip.csv', 'icici_bluechip.csv', 'kotak_bluechip.csv', 'nippon_large_cap.csv', 'sbi_bluechip.csv']

# %%
for file in csv_files:

    print("\n" + "="*60)
    print(f"Dataset: {file}")

    df = pd.read_csv(f"{data_path}/{file}")

    print("\nShape:")
    print(df.shape)

    print("\nData Types:")
    print(df.dtypes)

    print("\nFirst 5 Rows:")
    display(df.head())

    print("\nMissing Values:")
    print(df.isnull().sum())

    print("\nDuplicate Rows:")
    print(df.duplicated().sum())
# Out:
# ...
# Dataset: axis_bluechip.csv
#
# Shape:
# (3565, 2)
#
# Data Types:
# date     object
# nav     float64
# dtype: object
#
# First 5 Rows:
#          date        nav
# 0  01-06-2026  6156.7532
# 1  29-05-2026  6151.1139
# 2  27-05-2026  6146.6118
# 3  26-05-2026  6144.0004
# 4  25-05-2026  6144.8478
# Missing Values:
# date    0
# nav     0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# ...
# Dataset: icici_bluechip.csv
#
# Shape:
# (3307, 2)
#
# Data Types:
# date     object
# nav     float64
# dtype: object
#
# First 5 Rows:
#          date       nav
# 0  01-06-2026  103.0948
# 1  31-05-2026  104.3083
# 2  29-05-2026  104.3129
# 3  27-05-2026  105.9296
# 4  26-05-2026  105.5115
# Missing Values:
# date    0
# nav     0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# ...
# Dataset: kotak_bluechip.csv
#
# Shape:
# (3301, 2)
#
# Data Types:
# date     object
# nav     float64
# dtype: object
#
# First 5 Rows:
#          date       nav
# 0  01-06-2026  246.9814
# 1  29-05-2026  248.6673
# ...

# %%
summary = []

for file in csv_files:

    df = pd.read_csv(f"{data_path}/{file}")

    summary.append({
        "Dataset": file,
        "Rows": df.shape[0],
        "Columns": df.shape[1],
        "Missing Values": df.isnull().sum().sum(),
        "Duplicates": df.duplicated().sum()
    })

summary_df = pd.DataFrame(summary)
summary_df
# Out:
#                 Dataset  Rows  Columns  Missing Values  Duplicates
# 0     axis_bluechip.csv  3565        2               0           0
# 1    icici_bluechip.csv  3307        2               0           0
# 2    kotak_bluechip.csv  3301        2               0           0
# 3  nippon_large_cap.csv  3298        2               0           0
# 4      sbi_bluechip.csv  3236        2               0           0

# %% [markdown]
# lOad fund manager file

# %%
import pandas as pd

fund_master = pd.read_csv("../data/raw/01_fund_master.csv")

fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %% [markdown]
# EXPLORE FUND MANAGER

# %%
fund_master.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='object')

# %%
fund_master['fund_house'].unique()
# Out:
# array(['SBI Mutual Fund', 'HDFC Mutual Fund', 'ICICI Prudential MF',
#        'Nippon India MF', 'Kotak Mahindra MF', 'Axis Mutual Fund',
#        'Aditya Birla Sun Life MF', 'UTI Mutual Fund', 'Mirae Asset MF',
#        'DSP Mutual Fund'], dtype=object)

# %%
fund_master['category'].unique()
# Out:
# array(['Equity', 'Debt'], dtype=object)

# %%
fund_master['sub_category'].unique()
# Out:
# array(['Large Cap', 'Small Cap', 'Gilt', 'Mid Cap', 'Short Duration',
#        'Value', 'Liquid', 'Index/ETF', 'Flexi Cap', 'Index',
#        'Large & Mid Cap', 'ELSS'], dtype=object)

# %%
nav_history = pd.read_csv("../data/raw/02_nav_history.csv")

nav_history.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %% [markdown]
# AMFI CODE COLOMUNS

# %%
fund_master.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='object')

# %%
nav_history.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='object')

# %% [markdown]
# Validate code

# %%
master_codes = set(fund_master['amfi_code'])

nav_codes = set(nav_history['amfi_code'])

missing_codes = master_codes - nav_codes

print("Missing Codes:", len(missing_codes))

if len(missing_codes) > 0:
    print(missing_codes)
else:
    print("All AMFI codes from fund_master exist in nav_history")
# Out:
# Missing Codes: 0
# All AMFI codes from fund_master exist in nav_history

# %% [markdown]
# Data Qyality summary
#  # Day 1 Data Quality Summary
#
# * Loaded and inspected all provided datasets.
# * Verified dataset dimensions, schema, and sample records.
# * Explored fund master data and identified 10 unique fund houses.
# * Reviewed categories, sub-categories, and risk categories.
# * Validated AMFI codes between fund_master and nav_history datasets using Pandas merge operations.
# * No missing values or duplicate records were observed in the fetched NAV datasets.
# * Data is ready for cleaning and ETL processing in Day 2.
